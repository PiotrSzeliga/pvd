# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [24, 22, 20, 14]
ds = pd.Series(data)
ds
# Out:
# 0    24
# 1    22
# 2    20
# 3    14
# dtype: int64

# %%
ds.index = ['Novak Djokovic','Rafael Nadal','Roger Federer','Pete Sampras']

# %%
ds
# Out:
# Novak Djokovic    24
# Rafael Nadal      22
# Roger Federer     20
# Pete Sampras      14
# dtype: int64

# %%
ds.plot(title='number of Grand Slam tournaments won by tennis players', xlabel='Titles', ylabel='Player', kind='bar')
# Out:
# <Axes: title={'center': 'number of Grand Slam tournaments won by tennis players'}, xlabel='Titles', ylabel='Player'>
